# %%
import nibabel as nib
import numpy as np

# %%
# load the epi nifti
epi_img = nib.load('/Users/hongfusun/DATA/DTI/PRESCHOOL/PS14_017/dti_fa.nii')

# %%
epi_img_data = epi_img.get_data()
epi_img.affine
# Out:
# array([[ -0.78130001,   0.        ,   0.        ,  99.14060211],
#        [  0.        ,   0.77451771,   0.28924486, -73.40402222],
#        [  0.        ,  -0.102723  ,   2.18086767, -26.00863457],
#        [  0.        ,   0.        ,   0.        ,   1.        ]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
def show_slices(slices):
   """ Function to display row of image slices """
   fig, axes = plt.subplots(1, len(slices))
   for i, slice in enumerate(slices):
       axes[i].imshow(slice.T, cmap="gray", origin="lower")
   """ .T means transpose"""

slice_0 = epi_img_data[128, :, :]
slice_1 = epi_img_data[:, 132, :]
slice_2 = epi_img_data[:, :, 26]
show_slices([slice_0, slice_1, slice_2])
plt.suptitle("Center slices for EPI image")
# Out:
# Text(0.5,0.98,'Center slices for EPI image')

# %%
epi_img.affine
# Out:
# array([[ -0.78130001,   0.        ,   0.        ,  99.14060211],
#        [  0.        ,   0.77451771,   0.28924486, -73.40402222],
#        [  0.        ,  -0.102723  ,   2.18086767, -26.00863457],
#        [  0.        ,   0.        ,   0.        ,   1.        ]])

# %%
# load the GRE magnitude data
anat_img = nib.load('/Users/hongfusun/DATA/DTI/PRESCHOOL/PS14_017/QSM_SPGR_GE_halfpi/mag1.nii')

# %%
anat_img_data = anat_img.get_data()

# %%
# currently data arranged in DICOM LPS orientation
# flip to ANALYZE LAS orientation (this is how dcm2niix stores/arranges the data structure)
# anat_img_data = np.flip(anat_img_data,0)
anat_img_data = np.flip(anat_img_data,1)

# %%
show_slices([anat_img_data[100, :, :], anat_img_data[:, 20, :],anat_img_data[:, :, 20]])
plt.suptitle("Center slices for anatomical image")
# Out:
# Text(0.5,0.98,'Center slices for anatomical image')

# %%
type(dcm2nii_img.affine)
# Out:
# numpy.ndarray

# %%
help(nib.nifti1)
# Out:
# Help on module nibabel.nifti1 in nibabel:
#
# NAME
#     nibabel.nifti1 - Read / write access to NIfTI1 image format
#
# DESCRIPTION
#     NIfTI1 format defined at http://nifti.nimh.nih.gov/nifti-1/
#
# CLASSES
#     builtins.list(builtins.object)
#         Nifti1Extensions
#     builtins.object
#         Nifti1Extension
#             Nifti1DicomExtension
#     nibabel.analyze.AnalyzeImage(nibabel.spatialimages.SpatialImage)
#         Nifti1Pair
#             Nifti1Image
#     nibabel.spm99analyze.SpmAnalyzeHeader(nibabel.analyze.AnalyzeHeader)
#         Nifti1Header
#             Nifti1PairHeader
#
#     class Nifti1DicomExtension(Nifti1Extension)
#      |  NIfTI1 DICOM header extension
#      |
#      |  This class is a thin wrapper around pydicom to read a binary DICOM
#      |  byte string. If pydicom is available, content is exposed as a Dicom Dataset.
#      |  Otherwise, this silently falls back to the standard NiftiExtension class
# ...

# %%
newNII2 = nib.Nifti1Image(anat_img_data,dcm2nii_img.affine,dcm2nii_img.header)
newNII2.to_filename('/Users/hongfusun/DATA/DTI/PRESCHOOL/new.nii')

# %%
newNII.header.get_qform()
# Out:
# array([[ -0.78130001,   0.        ,   0.        ,  99.60939789],
#        [  0.        ,   0.78130001,   0.        , -67.54150391],
#        [  0.        ,   0.        ,   2.5       , -45.37519836],
#        [  0.        ,   0.        ,   0.        ,   1.        ]])

# %%
dcm2nii_img2 = nib.Nifti1Image(dcm2nii_img_data,dcm2nii_img.affine,dcm2nii_img.header)
dcm2nii_img2.to_filename('/Users/hongfusun/DATA/DTI/PRESCHOOL/newDicom2nii.nii')

# %%
dcm2nii_img.affine == dcm2nii_img.header.get_sform()
# Out:
# array([[ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True]])

# %%
# load the dcm2niix converted nifti
dcm2nii_img = nib.load('/Users/hongfusun/DATA/DTI/PRESCHOOL/PS14_017/Ax_T2_+_Phase_ART_(6echo)_5_Ax_T2_+_Phase_ART_(6echo)_20140522180831_5.nii')

# %%
dcm2nii_img_data = dcm2nii_img.get_data()

# %%
dcm2nii_img.header.get_qform_quaternion()
# Out:
# array([0., 0., 1., 0.], dtype=float128)

# %%
dcm2nii_img.header.get_best_affine()
# Out:
# array([[ -0.78130001,   0.        ,  -0.        ,  99.60939789],
#        [ -0.        ,   0.78130001,  -0.        , -67.54150391],
#        [  0.        ,   0.        ,   2.5       , -45.37519836],
#        [  0.        ,   0.        ,   0.        ,   1.        ]])

# %%
dcm2nii_img.header.get_sform()
# Out:
# array([[ -0.78130001,   0.        ,  -0.        ,  99.60939789],
#        [ -0.        ,   0.78130001,  -0.        , -67.54150391],
#        [  0.        ,   0.        ,   2.5       , -45.37519836],
#        [  0.        ,   0.        ,   0.        ,   1.        ]])

# %%
dcm2nii_img.affine
# Out:
# array([[ -0.78130001,   0.        ,  -0.        ,  99.60939789],
#        [ -0.        ,   0.78130001,  -0.        , -67.54150391],
#        [  0.        ,   0.        ,   2.5       , -45.37519836],
#        [  0.        ,   0.        ,   0.        ,   1.        ]])

# %%
dcm2nii_img.header.get_sform()
# Out:
# array([[ -0.78130001,   0.        ,  -0.        ,  99.60939789],
#        [ -0.        ,   0.78130001,  -0.        , -67.54150391],
#        [  0.        ,   0.        ,   2.5       , -45.37519836],
#        [  0.        ,   0.        ,   0.        ,   1.        ]])

# %% [markdown]
# dcm2nii_img.header.get_qform()

# %% [markdown]
# dcm2nii_img.header

# %%
show_slices([dcm2nii_img_data[100, :, :,0], dcm2nii_img_data[:, 20, :,0],dcm2nii_img_data[:, :, 20,0]])
plt.suptitle("Center slices for anatomical image")
# Out:
# Text(0.5,0.98,'Center slices for anatomical image')
